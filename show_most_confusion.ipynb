# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from torch.autograd import Variable

import glob
import os
import matplotlib.pyplot as plt
import torchvision.models as models
import cv2
import pickle
import random

# %%
class Classifier(nn.Module):
    def __init__(self, input_size, hidden_layers, output_size):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_layers)
        self.fc2 = nn.Linear(hidden_layers, hidden_layers)
        self.fc3 = nn.Linear(hidden_layers, output_size)
    
    def forward(self,data):
        x = F.tanh(self.fc1(data))
        x = F.tanh(self.fc2(x))
        x = self.fc3(x)
        return F.softmax(x,dim = 1)

# %%
def label2onehot(label_id):
    vector = np.zeros(101)
    vector[label_id] = 1
    return vector

def onehot2label(vector):
    return np.argmax(vector)

# %%
import pickle
with open("vgg16_data.pkl","rb") as f:
    temp = pickle.load(f)

# %%
with open("training_data.pkl","rb") as f:
    training_data = pickle.load(f)
    #random.shuffle(training_data)
    
with open("test_data.pkl","rb") as f:
    test_data = pickle.load(f)

# %%
records = temp["records"]
net = temp["net"]
net.cuda()
# Out:
# Classifier(
#   (fc1): Linear(in_features=4096, out_features=2048, bias=True)
#   (fc2): Linear(in_features=2048, out_features=2048, bias=True)
#   (fc3): Linear(in_features=2048, out_features=101, bias=True)
# )

# %%
with open("./food-101/meta/train.txt","r") as f:
    training_list = f.readlines()
with open("./food-101/meta/test.txt","r") as f:
    test_list = f.readlines()
    
with open('./food-101/meta/labels.txt','r') as f:
    labels = f.readlines()
    
training_list = ["./food-101/images/"+ path[:-1] +".jpg" for path in training_list]
test_list = ["./food-101/images/"+ path[:-1] +".jpg" for path in test_list]
labels = [label[:-1].replace(" ",'_').lower() for label in labels]

# %%
def validate(test_data,net):
    correct = 0
    for label, feature in test_data:
        x = Variable(torch.FloatTensor(feature)).cuda()
        output = net(x)
        if onehot2label(output.cpu().data.numpy()) == label:
            correct += 1
    return correct / len(test_data)

# %%
test_data_dict = {}
for i in range(len(labels)):
    test_data_dict[i] = []

for x in test_data:
    test_data_dict[x[0]].append(x)

# %%
test_acc_of_class = {
    "food_name":[],
    "accuracy":[]
}
for i in range(len(labels)):
    test_acc_of_class["food_name"].append(labels[i])
    test_acc_of_class["accuracy"].append(validate(test_data_dict[i],net))

# %%
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")

# %%
pd_test_acc_of_class = pd.DataFrame.from_dict(test_acc_of_class)

# %%
pd_test_acc_of_class.sort_values(by = ["accuracy"],ascending=False)[["food_name","accuracy"]][:25]
# Out:
#                food_name  accuracy
# 33               edamame     0.944
# 63              macarons     0.832
# 32             dumplings     0.828
# 64             miso_soup     0.784
# 54     hot_and_sour_soup     0.784
# 70              pad_thai     0.752
# 51             guacamole     0.748
# 40          french_fries     0.744
# 86               sashimi     0.736
# 69               oysters     0.732
# 75                   pho     0.728
# 91   spaghetti_carbonara     0.720
# 88         seaweed_salad     0.708
# 31                donuts     0.696
# 65               mussels     0.692
# 68           onion_rings     0.688
# 6               beignets     0.688
# 24          clam_chowder     0.672
# 60        lobster_bisque     0.672
# 35             escargots     0.664
# 76                 pizza     0.664
# 100              waffles     0.660
# 30          deviled_eggs     0.656
# 90   spaghetti_bolognese     0.640
# 45         frozen_yogurt     0.632

# %%
pd_test_acc_of_class.sort_values(by = ["accuracy"],ascending=False)[["food_name","accuracy"]][25:50]
# Out:
#                 food_name  accuracy
# 52                  gyoza     0.628
# 83        red_velvet_cake     0.624
# 41      french_onion_soup     0.620
# 27           creme_brulee     0.620
# 23                churros     0.616
# 7                bibimbap     0.608
# 55                hot_dog     0.604
# 29              cup_cakes     0.600
# 43         fried_calamari     0.596
# 78                poutine     0.592
# 61  lobster_roll_sandwich     0.584
# 34          eggs_benedict     0.560
# 11           caesar_salad     0.560
# 25          club_sandwich     0.548
# 92           spring_rolls     0.540
# 97               takoyaki     0.536
# 42           french_toast     0.528
# 98               tiramisu     0.528
# 94   strawberry_shortcake     0.512
# 71                 paella     0.512
# 2                 baklava     0.504
# 44             fried_rice     0.500
# 12                cannoli     0.496
# 1          baby_back_ribs     0.492
# 58              ice_cream     0.484

# %%
pd_test_acc_of_class.sort_values(by = ["accuracy"],ascending=False)[["food_name","accuracy"]][50:75]
# Out:
#                food_name  accuracy
# 19    chicken_quesadilla     0.480
# 17          cheese_plate     0.480
# 20         chicken_wings     0.480
# 59               lasagna     0.468
# 21        chocolate_cake     0.468
# 3         beef_carpaccio     0.456
# 48           greek_salad     0.452
# 38        fish_and_chips     0.452
# 53             hamburger     0.444
# 85                samosa     0.440
# 46          garlic_bread     0.436
# 80  pulled_pork_sandwich     0.428
# 28         croque_madame     0.424
# 62   macaroni_and_cheese     0.424
# 14           carrot_cake     0.420
# 72              pancakes     0.416
# 95                 sushi     0.416
# 84               risotto     0.412
# 13         caprese_salad     0.412
# 74           peking_duck     0.404
# 73           panna_cotta     0.396
# 81                 ramen     0.388
# 66                nachos     0.384
# 79             prime_rib     0.384
# 89      shrimp_and_grits     0.372

# %%
pd_test_acc_of_class.sort_values(by = ["accuracy"],ascending=False)[["food_name","accuracy"]][75:]
# Out:
#                   food_name  accuracy
# 50           grilled_salmon     0.368
# 67                 omelette     0.368
# 47                  gnocchi     0.360
# 36                  falafel     0.348
# 39                foie_gras     0.340
# 26               crab_cakes     0.336
# 9         breakfast_burrito     0.328
# 96                    tacos     0.324
# 18            chicken_curry     0.316
# 77                pork_chop     0.312
# 87                 scallops     0.308
# 4              beef_tartare     0.300
# 15                  ceviche     0.296
# 22         chocolate_mousse     0.288
# 5                beet_salad     0.276
# 37             filet_mignon     0.268
# 82                  ravioli     0.260
# 56         huevos_rancheros     0.252
# 8             bread_pudding     0.236
# 57                   hummus     0.232
# 0                 apple_pie     0.220
# 99             tuna_tartare     0.200
# 10               bruschetta     0.004
# 16               cheesecake     0.000
# 93                    steak     0.000
# 49  grilled_cheese_sandwich     0.000

# %%
pd.DataFrame.from_dict(records[10])[-1:]
# Out:
#        test    train
# 99  0.82804  0.82662

# %%
records[5]
# Out:
# {'test': [0.5158811881188119,
#   0.5815841584158415,
#   0.6029306930693069,
#   0.6145346534653465,
#   0.6195247524752475,
#   0.6286336633663366,
#   0.6293465346534654,
#   0.6280792079207921,
#   0.6256237623762376,
#   0.6285544554455446,
#   0.6383366336633663,
#   0.6413465346534654,
#   0.6455841584158416,
#   0.6527524752475248,
#   0.6507722772277228,
#   0.6570693069306931,
#   0.6653069306930693,
#   0.6683168316831684,
#   0.6725148514851486,
#   0.6752871287128713,
#   0.6790099009900991,
#   0.680990099009901,
#   0.6854257425742575,
#   0.6884752475247524,
#   0.6939405940594059,
#   0.6995643564356435,
#   0.6991287128712871,
#   0.7023762376237623,
#   0.7053069306930693,
#   0.7066930693069307,
#   0.7094257425742574,
#   0.7093069306930693,
#   0.7075247524752475,
#   0.707089108910891,
#   0.706059405940594,
#   0.7096633663366336,
#   0.7072475247524752,
#   0.7084356435643564,
#   0.7104554455445544,
#   0.7179405940594059,
#   0.7220990099009901,
#   0.7236039603960396,
#   0.7243960396039604,
#   0.7257425742574257,
#   0.7266534653465346,
#   0.7236435643564356,
#   0.7298613861386138,
#   0.7298217821782178,
#   0.728039603960396,
#   0.7276039603960396,
#   0.7288316831683168,
#   0.7304950495049505,
#   0.7326732673267327,
#   0.7282376237623762,
#   0.732039603960396,
#   0.7379009900990099,
#   0.7340990099009901,
#   0.7373861386138614,
#   0.7377821782178218,
#   0.7365148514851485,
#   0.7358811881188119,
#   0.7373465346534653,
#   0.741029702970297,
#   0.738970297029703,
#   0.736990099009901,
#   0.7386534653465346,
#   0.739049504950495,
#   0.7411089108910891,
#   0.7394455445544554,
#   0.7417821782178218,
#   0.7417821782178218,
#   0.7388910891089109,
#   0.7402772277227723,
#   0.7424158415841584,
#   0.743049504950495,
#   0.7405940594059406,
#   0.7441980198019802,
#   0.7424950495049505,
#   0.7421386138613861,
#   0.7421782178217822,
#   0.7413069306930693,
#   0.7411089108910891,
#   0.741980198019802,
#   0.7419405940594059,
#   0.7423366336633663,
#   0.7412277227722772,
#   0.742970297029703,
#   0.7388514851485148,
#   0.7406732673267327,
#   0.7402376237623762,
#   0.744950495049505,
#   0.7434851485148515,
#   0.7436435643564356,
#   0.7436435643564356,
#   0.748039603960396,
#   0.7416237623762376,
#   0.7432871287128713,
#   0.744950495049505,
#   0.7445544554455445,
#   0.7396435643564356],
#  'train': [0.4955839835241,
#   0.5597713440796335,
#   0.5795609067025757,
#   0.5933700344568101,
#   0.5998389375156772,
#   0.6089218054840456,
#   0.6121826606994336,
#   0.6120770459556154,
#   0.6138328910715936,
#   0.6177934439647775,
#   0.6281304870159874,
#   0.6332396002481947,
#   0.6371605476124467,
#   0.6441311207044503,
#   0.6448440202252235,
#   0.6522898596644091,
#   0.6594320567151174,
#   0.6655445100135979,
#   0.6697426960803728,
#   0.674376542965398,
#   0.6784295087594228,
#   0.6823768598096295,
#   0.6856773205539494,
#   0.6889513776123147,
#   0.6962123912498185,
#   0.6998825035975023,
#   0.7009386510356845,
#   0.7069850951192787,
#   0.7132163650045547,
#   0.7166620460216246,
#   0.7176653860878979,
#   0.719421231203876,
#   0.7208074247164904,
#   0.7212958929066497,
#   0.7221804163861275,
#   0.7235666098987419,
#   0.7246491610228788,
#   0.7245963536509696,
#   0.7282532641556761,
#   0.7349730022311115,
#   0.7414551071329558,
#   0.7438050351829115,
#   0.7447291641913211,
#   0.7460889540179809,
#   0.7478976065058682,
#   0.748214450737323,
#   0.751000039605529,
#   0.7527294810355526,
#   0.7538120321596895,
#   0.7548549777548946,
#   0.7549605924987128,
#   0.7571917039618731,
#   0.757284116862714,
#   0.757944209011578,
#   0.7643339010125814,
#   0.7653900484507637,
#   0.7653768466077865,
#   0.7678059857156059,
#   0.7681096281040833,
#   0.7684660778644699,
#   0.7688621331537883,
#   0.7695750326745614,
#   0.7709612261871758,
#   0.7710932446169485,
#   0.7727302731461312,
#   0.7750669993531097,
#   0.7762683670640421,
#   0.77744333108902,
#   0.778341056411475,
#   0.778288249039566,
#   0.7792519835769073,
#   0.7812454618664766,
#   0.7804401494448625,
#   0.7809550213209764,
#   0.7816283153128176,
#   0.7822356000897726,
#   0.7824996369493181,
#   0.7831465272552048,
#   0.783859426775978,
#   0.7840178488917052,
#   0.7837010046602506,
#   0.7845063170818646,
#   0.7851664092307286,
#   0.7852720239745469,
#   0.7850475926439331,
#   0.7864205843135702,
#   0.7860113271812745,
#   0.7869090525037296,
#   0.7862093548259337,
#   0.7862621621978428,
#   0.7871862912062524,
#   0.7879519980989346,
#   0.7877539704542754,
#   0.7887177049916169,
#   0.7888761271073442,
#   0.7903415316778222,
#   0.7896814395289582,
#   0.7899454763885039,
#   0.7908432017109589,
#   0.7912920643721864]}

# %%
def show_error_result(test_data, net,error_labels):
    error = 0
    for label, feature in test_data:
        x = Variable(torch.FloatTensor(feature)).cuda()
        output = net(x)
        predict_label_index = onehot2label(output.cpu().data.numpy())
        if predict_label_index != label:
#             print(predict_label_index)
            error += 1
            error_labels.append(predict_label_index)

# %%
# steak error
steak_error_labels = []
show_error_result(training_data_dict[93],net,steak_error_labels)
a = pd.Series([labels[lb] for lb in steak_error_labels]).value_counts().to_frame()
a.columns = ["Steak"]
a
# Out:
#                        Steak
# pork_chop                112
# baby_back_ribs            94
# filet_mignon              70
# grilled_salmon            45
# french_toast              41
# foie_gras                 21
# crab_cakes                20
# prime_rib                 19
# peking_duck               13
# hamburger                 13
# bread_pudding             12
# pulled_pork_sandwich      12
# tuna_tartare              12
# fried_calamari            11
# waffles                   11
# escargots                 11
# caprese_salad             10
# beef_tartare               9
# mussels                    9
# chicken_wings              8
# cheese_plate               8
# seaweed_salad              8
# gyoza                      7
# falafel                    7
# fish_and_chips             7
# beef_carpaccio             7
# paella                     6
# takoyaki                   6
# omelette                   6
# guacamole                  6
# ...                      ...
# chicken_curry              3
# gnocchi                    2
# shrimp_and_grits           2
# lasagna                    2
# nachos                     2
# croque_madame              2
# carrot_cake                2
# lobster_roll_sandwich      2
# ravioli                    2
# beet_salad                 2
# garlic_bread               2
# beignets                   2
# french_fries               2
# chocolate_mousse           2
# pancakes                   2
# risotto                    2
# pho                        1
# creme_brulee               1
# huevos_rancheros           1
# frozen_yogurt              1
# oysters                    1
# red_velvet_cake            1
# french_onion_soup          1
# scallops                   1
# panna_cotta                1
# ice_cream                  1
# baklava                    1
# bruschetta                 1
# bibimbap                   1
# dumplings                  1
#
# [81 rows x 1 columns]

# %%
# grilled_cheese_sandwich error
grilled_cheese_sandwich_error_labels = []
show_error_result(training_data_dict[49],net,grilled_cheese_sandwich_error_labels)
a = pd.Series([labels[lb] for lb in grilled_cheese_sandwich_error_labels]).value_counts().to_frame()
a.columns = ["Grilled_cheese_sandwich"]
a
# Out:
#                        Grilled_cheese_sandwich
# garlic_bread                                62
# pulled_pork_sandwich                        59
# club_sandwich                               56
# hamburger                                   48
# french_toast                                44
# grilled_salmon                              39
# gyoza                                       32
# fish_and_chips                              28
# omelette                                    21
# hot_dog                                     20
# samosa                                      20
# pork_chop                                   18
# churros                                     17
# baby_back_ribs                              16
# french_fries                                15
# lobster_roll_sandwich                       14
# tiramisu                                    13
# carrot_cake                                 13
# chicken_quesadilla                          11
# baklava                                     10
# breakfast_burrito                            9
# guacamole                                    9
# spring_rolls                                 9
# french_onion_soup                            8
# crab_cakes                                   8
# waffles                                      8
# foie_gras                                    8
# chicken_curry                                6
# cheese_plate                                 6
# hummus                                       6
# ...                                        ...
# escargots                                    3
# sushi                                        3
# peking_duck                                  2
# caesar_salad                                 2
# sashimi                                      2
# tuna_tartare                                 2
# scallops                                     2
# bread_pudding                                2
# chicken_wings                                2
# prime_rib                                    2
# spaghetti_bolognese                          2
# pancakes                                     2
# paella                                       1
# macarons                                     1
# pad_thai                                     1
# miso_soup                                    1
# greek_salad                                  1
# fried_calamari                               1
# macaroni_and_cheese                          1
# beef_tartare                                 1
# edamame                                      1
# creme_brulee                                 1
# strawberry_shortcake                         1
# eggs_benedict                                1
# ravioli                                      1
# risotto                                      1
# filet_mignon                                 1
# chocolate_mousse                             1
# chocolate_cake                               1
# gnocchi                                      1
#
# [77 rows x 1 columns]

# %%
#cheesecake error
cheesecake_error_labels = []
show_error_result(training_data_dict[16],net,cheesecake_error_labels)
a = pd.Series([labels[lb] for lb in cheesecake_error_labels]).value_counts().to_frame()
a.columns = ["Cheesecake"]
a
# Out:
#                        Cheesecake
# tiramisu                       85
# chocolate_cake                 71
# panna_cotta                    64
# strawberry_shortcake           56
# red_velvet_cake                52
# foie_gras                      40
# carrot_cake                    32
# donuts                         24
# chocolate_mousse               23
# waffles                        22
# apple_pie                      19
# french_toast                   19
# bread_pudding                  18
# tuna_tartare                   17
# cheese_plate                   15
# baby_back_ribs                 14
# cannoli                        14
# cup_cakes                      10
# pancakes                        9
# deviled_eggs                    8
# ice_cream                       8
# beignets                        7
# baklava                         6
# peking_duck                     6
# samosa                          6
# churros                         6
# lobster_bisque                  5
# hummus                          5
# sashimi                         5
# creme_brulee                    5
# ...                           ...
# oysters                         2
# lasagna                         2
# scallops                        2
# grilled_salmon                  2
# garlic_bread                    2
# falafel                         2
# club_sandwich                   2
# guacamole                       2
# frozen_yogurt                   1
# omelette                        1
# lobster_roll_sandwich           1
# chicken_quesadilla              1
# fried_rice                      1
# edamame                         1
# escargots                       1
# miso_soup                       1
# breakfast_burrito               1
# chicken_curry                   1
# seaweed_salad                   1
# pulled_pork_sandwich            1
# ramen                           1
# paella                          1
# greek_salad                     1
# hamburger                       1
# croque_madame                   1
# spring_rolls                    1
# spaghetti_carbonara             1
# poutine                         1
# clam_chowder                    1
# dumplings                       1
#
# [72 rows x 1 columns]

# %%
#bruschetta error
bruschetta_error_labels = []
show_error_result(training_data_dict[10],net,bruschetta_error_labels)
a = pd.Series([labels[lb] for lb in bruschetta_error_labels]).value_counts().to_frame()
a.columns = ["Bruschetta"]
a
# Out:
#                        Bruschetta
# lobster_roll_sandwich          61
# beef_carpaccio                 39
# caprese_salad                  38
# sushi                          27
# takoyaki                       27
# tuna_tartare                   26
# ceviche                        26
# pizza                          25
# tacos                          21
# grilled_salmon                 18
# waffles                        18
# beef_tartare                   17
# huevos_rancheros               17
# french_toast                   16
# crab_cakes                     15
# nachos                         14
# pork_chop                      14
# gyoza                          14
# beet_salad                     13
# eggs_benedict                  12
# greek_salad                    11
# foie_gras                      11
# donuts                         10
# scallops                       10
# pulled_pork_sandwich           10
# hot_dog                        10
# ravioli                        10
# caesar_salad                   10
# omelette                       10
# gnocchi                         9
# ...                           ...
# bread_pudding                   3
# seaweed_salad                   3
# croque_madame                   3
# paella                          3
# fried_calamari                  3
# baklava                         2
# fried_rice                      2
# frozen_yogurt                   2
# carrot_cake                     2
# chicken_wings                   2
# filet_mignon                    2
# club_sandwich                   2
# churros                         2
# pad_thai                        2
# chicken_quesadilla              1
# fish_and_chips                  1
# chocolate_mousse                1
# pho                             1
# tiramisu                        1
# beignets                        1
# macaroni_and_cheese             1
# onion_rings                     1
# hummus                          1
# ramen                           1
# ice_cream                       1
# bibimbap                        1
# spaghetti_bolognese             1
# prime_rib                       1
# panna_cotta                     1
# lobster_bisque                  1
#
# [85 rows x 1 columns]

# %%
#tuna_tartare error
tuna_tartare_error_labels = []
show_error_result(training_data_dict[99],net,tuna_tartare_error_labels)
a = pd.Series([labels[lb] for lb in tuna_tartare_error_labels]).value_counts().to_frame()
a.columns = ["Tuna_tartare"]
a
# Out:
#                        Tuna_tartare
# ceviche                          18
# beef_tartare                     18
# panna_cotta                      13
# foie_gras                        12
# guacamole                        12
# crab_cakes                       12
# bread_pudding                     9
# beet_salad                        8
# sashimi                           8
# gyoza                             7
# spring_rolls                      7
# beef_carpaccio                    7
# sushi                             7
# tiramisu                          7
# samosa                            6
# deviled_eggs                      6
# chocolate_cake                    6
# donuts                            6
# filet_mignon                      5
# lobster_roll_sandwich             5
# omelette                          5
# huevos_rancheros                  5
# churros                           5
# caprese_salad                     5
# greek_salad                       5
# cheese_plate                      5
# fried_calamari                    4
# waffles                           4
# hamburger                         4
# chocolate_mousse                  4
# ...                             ...
# chicken_wings                     2
# chicken_quesadilla                2
# pork_chop                         2
# breakfast_burrito                 2
# pancakes                          2
# caesar_salad                      2
# pizza                             2
# creme_brulee                      2
# peking_duck                       2
# strawberry_shortcake              2
# hot_dog                           2
# red_velvet_cake                   2
# poutine                           2
# frozen_yogurt                     1
# garlic_bread                      1
# prime_rib                         1
# french_fries                      1
# edamame                           1
# hot_and_sour_soup                 1
# cannoli                           1
# croque_madame                     1
# spaghetti_bolognese               1
# macarons                          1
# paella                            1
# club_sandwich                     1
# ramen                             1
# risotto                           1
# fish_and_chips                    1
# chicken_curry                     1
# lasagna                           1
#
# [77 rows x 1 columns]
