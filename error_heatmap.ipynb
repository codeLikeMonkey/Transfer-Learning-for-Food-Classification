# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from torch.autograd import Variable

import glob
import os
import matplotlib.pyplot as plt
import torchvision.models as models
import cv2
import pickle
import random

# %%
class Classifier(nn.Module):
    def __init__(self, input_size, hidden_layers, output_size):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_layers)
        self.fc2 = nn.Linear(hidden_layers, hidden_layers)
        self.fc3 = nn.Linear(hidden_layers, output_size)
    
    def forward(self,data):
        x = F.tanh(self.fc1(data))
        x = F.tanh(self.fc2(x))
        x = self.fc3(x)
        return F.softmax(x,dim = 1)

# %%
def label2onehot(label_id):
    vector = np.zeros(101)
    vector[label_id] = 1
    return vector

def onehot2label(vector):
    return np.argmax(vector)

# %%
def chunk(data,batch_size):
    batches = []
    x = np.arange(len(data) // batch_size + 2)*batch_size
#     print(x)
    for b,e in zip(x[0:-1],x[1:]):
        batches.append(data[b:e])
    return batches

# %%
def encode_batch(minibatch):
    label_batch = []
    feature_batch_vector = []
    for label, feature in minibatch:
        label_batch.append(label)
        feature_batch_vector.append(feature.squeeze())
    return np.array(label_batch), np.array(feature_batch_vector)

# %%
with open("training_data.pkl","rb") as f:
    training_data = pickle.load(f)
    #random.shuffle(training_data)
    
with open("test_data.pkl","rb") as f:
    test_data = pickle.load(f)

# %%
with open("vgg16_data.pkl","rb") as f:
    temp = pickle.load(f)

# %%
net = temp["net"]

# %%
net.cuda()
# Out:
# Classifier(
#   (fc1): Linear(in_features=4096, out_features=2048, bias=True)
#   (fc2): Linear(in_features=2048, out_features=2048, bias=True)
#   (fc3): Linear(in_features=2048, out_features=101, bias=True)
# )

# %%
onehot2label(net(torch.FloatTensor(test_data[0][1]).cuda()).cpu().data.numpy()[0])
# Out:
# 85

# %%
with open("./food-101/meta/train.txt","r") as f:
    training_list = f.readlines()
with open("./food-101/meta/test.txt","r") as f:
    test_list = f.readlines()
    
with open('./food-101/meta/labels.txt','r') as f:
    labels = f.readlines()
    
training_list = ["./food-101/images/"+ path[:-1] +".jpg" for path in training_list]
test_list = ["./food-101/images/"+ path[:-1] +".jpg" for path in test_list]
labels = [label[:-1].replace(" ",'_').lower() for label in labels]

# %%
def validate(test_data,net):
    correct = 0
    for label, feature in test_data:
        x = Variable(torch.FloatTensor(feature)).cuda()
        output = net(x)
        if onehot2label(output.cpu().data.numpy()) == label:
            correct += 1
    return correct / len(test_data)

# %%
labels[100]
# Out:
# 'waffles'

# %%
training_data_dict = {}
for i in range(len(labels)):
    training_data_dict[i] = []

for x in training_data:
    training_data_dict[x[0]].append(x)

# %%
test_data_dict = {}
for i in range(len(labels)):
    test_data_dict[i] = []

for x in test_data:
    test_data_dict[x[0]].append(x)

# %%
training_acc_of_class = {
    "food_name":[],
    "accuracy":[]
}
for i in range(len(labels)):
    training_acc_of_class["food_name"].append(labels[i])
    training_acc_of_class["accuracy"].append(validate(training_data_dict[i],net))

# %%
test_acc_of_class = {
    "food_name":[],
    "accuracy":[]
}
for i in range(len(labels)):
    test_acc_of_class["food_name"].append(labels[i])
    test_acc_of_class["accuracy"].append(validate(test_data_dict[i],net))

# %%
training_acc_of_class
# Out:
# {'accuracy': [0.6386666666666667,
#   0.792,
#   0.8226666666666667,
#   0.8133333333333334,
#   0.7026666666666667,
#   0.7426666666666667,
#   0.9213333333333333,
#   0.8706666666666667,
#   0.6435246995994659,
#   0.7346666666666667,
#   0.013333333333333334,
#   0.836,
#   0.8213333333333334,
#   0.7573333333333333,
#   0.7346666666666667,
#   0.6586666666666666,
#   0.0,
#   0.8493333333333334,
#   0.6853333333333333,
#   0.7826666666666666,
#   0.8186666666666667,
#   0.8373333333333334,
#   0.7146666666666667,
#   0.8426666666666667,
#   0.8213333333333334,
#   0.8533333333333334,
#   0.6466666666666666,
#   0.8533333333333334,
#   0.784,
#   0.9066666666666666,
#   0.8626666666666667,
#   0.824,
#   0.8346666666666667,
#   0.9626666666666667,
#   0.8546666666666667,
#   0.7586666666666667,
#   0.6613333333333333,
#   0.7546666666666667,
#   0.8586666666666667,
#   0.6533333333333333,
#   0.8946666666666667,
#   0.8466666666666667,
#   0.7506666666666667,
#   0.824,
#   0.816,
#   0.9,
#   0.8066666666666666,
#   0.6946666666666667,
#   0.852,
#   0.0013333333333333333,
#   0.6693333333333333,
#   0.8546666666666667,
#   0.812,
#   0.836,
#   0.932,
#   0.816,
#   0.6506666666666666,
#   0.572,
#   0.788,
#   0.7596795727636849,
#   0.8426666666666667,
#   0.8106666666666666,
#   0.784,
#   0.9493333333333334,
#   0.9253333333333333,
#   0.8893333333333333,
#   0.8026666666666666,
#   0.6453333333333333,
#   0.9093333333333333,
#   0.9053333333333333,
#   0.9106666666666666,
#   0.848,
#   0.7813333333333333,
#   0.8173333333333334,
#   0.7266666666666667,
#   0.9373333333333334,
#   0.9,
#   0.6933333333333334,
#   0.8653333333333333,
#   0.7773333333333333,
#   0.76,
#   0.824,
#   0.608,
#   0.888,
#   0.7666666666666667,
#   0.7653333333333333,
#   0.8773333333333333,
#   0.6733333333333333,
#   0.9173333333333333,
#   0.7813333333333333,
#   0.92,
#   0.9186666666666666,
#   0.7893333333333333,
#   0.0,
#   0.8626666666666667,
#   0.7266666666666667,
#   0.728,
#   0.7933333333333333,
#   0.7933333333333333,
#   0.572,
#   0.7693333333333333],
#  'food_name': ['apple_pie',
#   'baby_back_ribs',
#   'baklava',
#   'beef_carpaccio',
#   'beef_tartare',
#   'beet_salad',
#   'beignets',
#   'bibimbap',
#   'bread_pudding',
#   'breakfast_burrito',
#   'bruschetta',
#   'caesar_salad',
#   'cannoli',
#   'caprese_salad',
#   'carrot_cake',
#   'ceviche',
#   'cheesecake',
#   'cheese_plate',
#   'chicken_curry',
#   'chicken_quesadilla',
#   'chicken_wings',
#   'chocolate_cake',
#   'chocolate_mousse',
#   'churros',
#   'clam_chowder',
#   'club_sandwich',
#   'crab_cakes',
#   'creme_brulee',
#   'croque_madame',
#   'cup_cakes',
#   'deviled_eggs',
#   'donuts',
#   'dumplings',
#   'edamame',
#   'eggs_benedict',
#   'escargots',
#   'falafel',
#   'filet_mignon',
#   'fish_and_chips',
#   'foie_gras',
#   'french_fries',
#   'french_onion_soup',
#   'french_toast',
#   'fried_calamari',
#   'fried_rice',
#   'frozen_yogurt',
#   'garlic_bread',
#   'gnocchi',
#   'greek_salad',
#   'grilled_cheese_sandwich',
#   'grilled_salmon',
#   'guacamole',
#   'gyoza',
#   'hamburger',
#   'hot_and_sour_soup',
#   'hot_dog',
#   'huevos_rancheros',
#   'hummus',
#   'ice_cream',
#   'lasagna',
#   'lobster_bisque',
#   'lobster_roll_sandwich',
#   'macaroni_and_cheese',
#   'macarons',
#   'miso_soup',
#   'mussels',
#   'nachos',
#   'omelette',
#   'onion_rings',
#   'oysters',
#   'pad_thai',
#   'paella',
#   'pancakes',
#   'panna_cotta',
#   'peking_duck',
#   'pho',
#   'pizza',
#   'pork_chop',
#   'poutine',
#   'prime_rib',
#   'pulled_pork_sandwich',
#   'ramen',
#   'ravioli',
#   'red_velvet_cake',
#   'risotto',
#   'samosa',
#   'sashimi',
#   'scallops',
#   'seaweed_salad',
#   'shrimp_and_grits',
#   'spaghetti_bolognese',
#   'spaghetti_carbonara',
#   'spring_rolls',
#   'steak',
#   'strawberry_shortcake',
#   'sushi',
#   'tacos',
#   'takoyaki',
#   'tiramisu',
#   'tuna_tartare',
#   'waffles']}

# %%
test_acc_of_class
# Out:
# {'accuracy': [0.22,
#   0.492,
#   0.504,
#   0.456,
#   0.3,
#   0.276,
#   0.688,
#   0.608,
#   0.236,
#   0.328,
#   0.004,
#   0.56,
#   0.496,
#   0.412,
#   0.42,
#   0.296,
#   0.0,
#   0.48,
#   0.316,
#   0.48,
#   0.48,
#   0.468,
#   0.288,
#   0.616,
#   0.672,
#   0.548,
#   0.336,
#   0.62,
#   0.424,
#   0.6,
#   0.656,
#   0.696,
#   0.828,
#   0.944,
#   0.56,
#   0.664,
#   0.348,
#   0.268,
#   0.452,
#   0.34,
#   0.744,
#   0.62,
#   0.528,
#   0.596,
#   0.5,
#   0.632,
#   0.436,
#   0.36,
#   0.452,
#   0.0,
#   0.368,
#   0.748,
#   0.628,
#   0.444,
#   0.784,
#   0.604,
#   0.252,
#   0.232,
#   0.484,
#   0.468,
#   0.672,
#   0.584,
#   0.424,
#   0.832,
#   0.784,
#   0.692,
#   0.384,
#   0.368,
#   0.688,
#   0.732,
#   0.752,
#   0.512,
#   0.416,
#   0.396,
#   0.404,
#   0.728,
#   0.664,
#   0.312,
#   0.592,
#   0.384,
#   0.428,
#   0.388,
#   0.26,
#   0.624,
#   0.412,
#   0.44,
#   0.736,
#   0.308,
#   0.708,
#   0.372,
#   0.64,
#   0.72,
#   0.54,
#   0.0,
#   0.512,
#   0.416,
#   0.324,
#   0.536,
#   0.528,
#   0.2,
#   0.66],
#  'food_name': ['apple_pie',
#   'baby_back_ribs',
#   'baklava',
#   'beef_carpaccio',
#   'beef_tartare',
#   'beet_salad',
#   'beignets',
#   'bibimbap',
#   'bread_pudding',
#   'breakfast_burrito',
#   'bruschetta',
#   'caesar_salad',
#   'cannoli',
#   'caprese_salad',
#   'carrot_cake',
#   'ceviche',
#   'cheesecake',
#   'cheese_plate',
#   'chicken_curry',
#   'chicken_quesadilla',
#   'chicken_wings',
#   'chocolate_cake',
#   'chocolate_mousse',
#   'churros',
#   'clam_chowder',
#   'club_sandwich',
#   'crab_cakes',
#   'creme_brulee',
#   'croque_madame',
#   'cup_cakes',
#   'deviled_eggs',
#   'donuts',
#   'dumplings',
#   'edamame',
#   'eggs_benedict',
#   'escargots',
#   'falafel',
#   'filet_mignon',
#   'fish_and_chips',
#   'foie_gras',
#   'french_fries',
#   'french_onion_soup',
#   'french_toast',
#   'fried_calamari',
#   'fried_rice',
#   'frozen_yogurt',
#   'garlic_bread',
#   'gnocchi',
#   'greek_salad',
#   'grilled_cheese_sandwich',
#   'grilled_salmon',
#   'guacamole',
#   'gyoza',
#   'hamburger',
#   'hot_and_sour_soup',
#   'hot_dog',
#   'huevos_rancheros',
#   'hummus',
#   'ice_cream',
#   'lasagna',
#   'lobster_bisque',
#   'lobster_roll_sandwich',
#   'macaroni_and_cheese',
#   'macarons',
#   'miso_soup',
#   'mussels',
#   'nachos',
#   'omelette',
#   'onion_rings',
#   'oysters',
#   'pad_thai',
#   'paella',
#   'pancakes',
#   'panna_cotta',
#   'peking_duck',
#   'pho',
#   'pizza',
#   'pork_chop',
#   'poutine',
#   'prime_rib',
#   'pulled_pork_sandwich',
#   'ramen',
#   'ravioli',
#   'red_velvet_cake',
#   'risotto',
#   'samosa',
#   'sashimi',
#   'scallops',
#   'seaweed_salad',
#   'shrimp_and_grits',
#   'spaghetti_bolognese',
#   'spaghetti_carbonara',
#   'spring_rolls',
#   'steak',
#   'strawberry_shortcake',
#   'sushi',
#   'tacos',
#   'takoyaki',
#   'tiramisu',
#   'tuna_tartare',
#   'waffles']}

# %%
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")

# %%
pd_training_acc_of_class = pd.DataFrame.from_dict(training_acc_of_class)
pd_test_acc_of_class = pd.DataFrame.from_dict(test_acc_of_class)

# %%
pd_training_acc_of_class.sort_values(by = ["accuracy"],ascending=False)
# Out:
#     accuracy                food_name
# 33  0.962667                  edamame
# 63  0.949333                 macarons
# 75  0.937333                      pho
# 54  0.932000        hot_and_sour_soup
# 64  0.925333                miso_soup
# 6   0.921333                 beignets
# 90  0.920000      spaghetti_bolognese
# 91  0.918667      spaghetti_carbonara
# 88  0.917333            seaweed_salad
# 70  0.910667                 pad_thai
# 68  0.909333              onion_rings
# 29  0.906667                cup_cakes
# 69  0.905333                  oysters
# 76  0.900000                    pizza
# 45  0.900000            frozen_yogurt
# 40  0.894667             french_fries
# 65  0.889333                  mussels
# 83  0.888000          red_velvet_cake
# 86  0.877333                  sashimi
# 7   0.870667                 bibimbap
# 78  0.865333                  poutine
# 94  0.862667     strawberry_shortcake
# 30  0.862667             deviled_eggs
# 38  0.858667           fish_and_chips
# 51  0.854667                guacamole
# 34  0.854667            eggs_benedict
# 25  0.853333            club_sandwich
# 27  0.853333             creme_brulee
# 48  0.852000              greek_salad
# 17  0.849333             cheese_plate
# ..       ...                      ...
# 37  0.754667             filet_mignon
# 42  0.750667             french_toast
# 5   0.742667               beet_salad
# 14  0.734667              carrot_cake
# 9   0.734667        breakfast_burrito
# 96  0.728000                    tacos
# 74  0.726667              peking_duck
# 95  0.726667                    sushi
# 22  0.714667         chocolate_mousse
# 4   0.702667             beef_tartare
# 47  0.694667                  gnocchi
# 77  0.693333                pork_chop
# 18  0.685333            chicken_curry
# 87  0.673333                 scallops
# 50  0.669333           grilled_salmon
# 36  0.661333                  falafel
# 15  0.658667                  ceviche
# 39  0.653333                foie_gras
# 56  0.650667         huevos_rancheros
# 26  0.646667               crab_cakes
# 67  0.645333                 omelette
# 8   0.643525            bread_pudding
# 0   0.638667                apple_pie
# 82  0.608000                  ravioli
# 57  0.572000                   hummus
# 99  0.572000             tuna_tartare
# 10  0.013333               bruschetta
# 49  0.001333  grilled_cheese_sandwich
# 93  0.000000                    steak
# 16  0.000000               cheesecake
#
# [101 rows x 2 columns]

# %%
pd_training_acc_of_class.to_csv("pd_training_acc_of_class.csv")

# %%
def show_error_result(test_data, net,error_labels):
    error = 0
    for label, feature in test_data:
        x = Variable(torch.FloatTensor(feature)).cuda()
        output = net(x)
        predict_label_index = onehot2label(output.cpu().data.numpy())
        if predict_label_index != label:
#             print(predict_label_index)
            error += 1
            error_labels.append(predict_label_index)

# %%
error_map = np.zeros((len(labels),len(labels)))

for i in range(len(labels)):
    error_labels = []
    show_error_result(training_data_dict[i], net,error_labels)
    for j in error_labels:
        error_map[i,j] += 1

# %%
pd_training_acc_of_class.sort_values(by = ["accuracy"])[:20]
# Out:
#     accuracy                food_name
# 93  0.000000                    steak
# 16  0.000000               cheesecake
# 49  0.001333  grilled_cheese_sandwich
# 10  0.013333               bruschetta
# 57  0.572000                   hummus
# 99  0.572000             tuna_tartare
# 82  0.608000                  ravioli
# 0   0.638667                apple_pie
# 8   0.643525            bread_pudding
# 67  0.645333                 omelette
# 26  0.646667               crab_cakes
# 56  0.650667         huevos_rancheros
# 39  0.653333                foie_gras
# 15  0.658667                  ceviche
# 36  0.661333                  falafel
# 50  0.669333           grilled_salmon
# 87  0.673333                 scallops
# 18  0.685333            chicken_curry
# 77  0.693333                pork_chop
# 47  0.694667                  gnocchi

# %%
top_error_index = np.sum(error_map,axis = 0).argsort()

# %%
sns.heatmap(error_map,cmap="YlGnBu")

# %%
sns.heatmap(error_map[top_error_index[:5],:],cmap="YlGnBu")

# %%
pd.Series([labels[lb] for lb in steak_error_labels]).value_counts()
# Out:
# pork_chop                112
# baby_back_ribs            94
# filet_mignon              70
# grilled_salmon            45
# french_toast              41
# foie_gras                 21
# crab_cakes                20
# prime_rib                 19
# hamburger                 13
# peking_duck               13
# pulled_pork_sandwich      12
# bread_pudding             12
# tuna_tartare              12
# escargots                 11
# waffles                   11
# fried_calamari            11
# caprese_salad             10
# beef_tartare               9
# mussels                    9
# chicken_wings              8
# cheese_plate               8
# seaweed_salad              8
# gyoza                      7
# falafel                    7
# beef_carpaccio             7
# fish_and_chips             7
# omelette                   6
# chocolate_cake             6
# pad_thai                   6
# takoyaki                   6
#                         ...
# churros                    3
# nachos                     2
# lasagna                    2
# beet_salad                 2
# ravioli                    2
# beignets                   2
# garlic_bread               2
# french_fries               2
# pancakes                   2
# carrot_cake                2
# lobster_roll_sandwich      2
# risotto                    2
# gnocchi                    2
# shrimp_and_grits           2
# croque_madame              2
# chocolate_mousse           2
# bibimbap                   1
# huevos_rancheros           1
# french_onion_soup          1
# pho                        1
# baklava                    1
# red_velvet_cake            1
# scallops                   1
# frozen_yogurt              1
# ice_cream                  1
# panna_cotta                1
# bruschetta                 1
# dumplings                  1
# oysters                    1
# creme_brulee               1
# Length: 81, dtype: int64

# %%
# steak error
bruschetta_error_labels = []
show_error_result(training_data_dict[10],net,bruschetta_error_labels)

# %%
pd.Series([labels[lb] for lb in bruschetta_error_labels]).value_counts()
# Out:
# lobster_roll_sandwich    61
# beef_carpaccio           39
# caprese_salad            38
# sushi                    27
# takoyaki                 27
# tuna_tartare             26
# ceviche                  26
# pizza                    25
# tacos                    21
# grilled_salmon           18
# waffles                  18
# beef_tartare             17
# huevos_rancheros         17
# french_toast             16
# crab_cakes               15
# gyoza                    14
# nachos                   14
# pork_chop                14
# beet_salad               13
# eggs_benedict            12
# foie_gras                11
# greek_salad              11
# omelette                 10
# ravioli                  10
# pulled_pork_sandwich     10
# hot_dog                  10
# scallops                 10
# donuts                   10
# caesar_salad             10
# gnocchi                   9
#                          ..
# fried_calamari            3
# paella                    3
# escargots                 3
# bread_pudding             3
# croque_madame             3
# filet_mignon              2
# fried_rice                2
# frozen_yogurt             2
# carrot_cake               2
# club_sandwich             2
# pad_thai                  2
# churros                   2
# baklava                   2
# chicken_wings             2
# ice_cream                 1
# panna_cotta               1
# beignets                  1
# spaghetti_bolognese       1
# bibimbap                  1
# fish_and_chips            1
# prime_rib                 1
# ramen                     1
# hummus                    1
# onion_rings               1
# chicken_quesadilla        1
# pho                       1
# chocolate_mousse          1
# macaroni_and_cheese       1
# lobster_bisque            1
# tiramisu                  1
# Length: 85, dtype: int64
